# %%
import torch
import torchvision

# %%
tot_loader = torchvision.datasets.ImageFolder('Dataset/MovieGenre/content/sorted_movie_posters_paligema')

# %%
import matplotlib.pyplot as plt
plt.imshow(tot_loader[0][0])
tot_loader[0][1]
# Out:
# 0
